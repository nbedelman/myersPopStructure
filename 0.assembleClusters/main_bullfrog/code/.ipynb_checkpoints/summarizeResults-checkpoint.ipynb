# %%
import ipyrad as ip
import ipyrad.analysis as ipa 
import sys
import os
import pandas as pd
import toyplot
from os.path import join

# %%
exec(open('/home/nbe4/project/myersPopStructure/0.assembleClusters/code/generatePopDict.py').read())

# %%
workDir="/home/nbe4/project/myersPopStructure/0.assembleClusters/main_bullfrog/"

# %%
# for f in os.listdir(workDir):
#     if "json" in f:
#         try:
#             thisRun=ip.load_json(join(workDir,f))
# #             outDir=join(workDir,f.split(".")[0]+"_outfiles")
# #             mainStats=join(outDir,f.split(".")[0]+"_finalStats.txt")
# #             pandas.DataFrame.to_csv(thisRun.stats, mainStats)
#         except FileNotFoundError:
#             pass

# %%
vcffile=workDir+"/myersPopGen_bullfrog_outfiles/myersPopGen_bullfrog.vcf"
hdfFile=workDir+"/myersPopGen_bullfrog_outfiles/myersPopGen_bullfrog.snps.hdf5"

# %%
#generate population dictionary
imap = makeDict("/home/nbe4/project/myersPopStructure/0.assembleClusters/main_smallRamp/data/popfile.txt") 

#imap

# %%
minmap = {i: 0.0 for i in imap}
#minmap

# %%
pca=ipa.pca(
    data=hdfFile,
    imap=imap,
    minmap=minmap,
    mincov=0.01,
    impute_method="sample")
# Out:
# ---------------------------------------------------------------------------
# IPyradError                               Traceback (most recent call last)
# <ipython-input-7-2cbbe6c0b1d1> in <module>
# ----> 1 pca=ipa.pca(
#       2     data=hdfFile,
#       3     imap=imap,
#       4     minmap=minmap,
#       5     mincov=0.01,
#
# /gpfs/loomis/project/skelly/nbe4/conda_envs/ipyrad/lib/python3.8/site-packages/ipyrad/analysis/pca.py in __init__(self, data, impute_method, imap, minmap, mincov, quiet, topcov, niters, ld_block_size)
#     160         # load .snps and .snpsmap from HDF5
#     161         first = (True if isinstance(self.impute_method, int) else quiet)
# --> 162         ext = SNPsExtracter(
#     163             self.data, self.imap, self.minmap, self.mincov, quiet=first,
#     164         )
#
# /gpfs/loomis/project/skelly/nbe4/conda_envs/ipyrad/lib/python3.8/site-packages/ipyrad/analysis/snps_extracter.py in __init__(self, data, imap, minmap, mincov, quiet)
#      66         if self.data.endswith(".vcf"):
#      67             raise NotImplementedError("VCF parsing coming soon.")
# ---> 68         self.parse_names_from_hdf5()
#      69
#      70
#
# /gpfs/loomis/project/skelly/nbe4/conda_envs/ipyrad/lib/python3.8/site-packages/ipyrad/analysis/snps_extracter.py in parse_names_from_hdf5(self)
#      88             badnames = set(self.names).difference(self.dbnames)
#      89             if badnames:
# ---> 90                 raise IPyradError(
#      91                     "Samples [{}] are not in data file: {}"
#      92                     .format(badnames, self.data))
#
# IPyradError: Samples [{'YMF2018_026_S23001.trim', 'YMF2018_164_Dup001.trim', 'YMF2018_027_S35001.trim', 'YMF2018_347_Dup001.trim', 'YMF2018_062_Dup001.trim', 'YMF2018_035_S47001.trim'}] are not in data file: /gpfs/loomis/project/skelly/nbe4/myersPopStructure/0.assembleClusters/main_bullfrog/myersPopGen_bullfrog_outfiles/myersPopGen_bullfrog.snps.hdf5

# %%
for i in ['YMF2018_026_S23001.trim', 'YMF2018_027_S35001.trim', 'YMF2018_347_Dup001.trim', 'YMF2018_164_Dup001.trim', 'YMF2018_062_Dup001.trim', 'YMF2018_035_S47001.trim']:
    for k in imap.keys():
        if i in imap[k]:
            imap[k].remove(i)

# %%
pca=ipa.pca(
    data=hdfFile,
    imap=imap,
    minmap=minmap,
    mincov=0.5,
    impute_method=7)

# %%
pca.run()
# Out:
# Subsampling SNPs: 14682/65751

# %%
df = pd.DataFrame(pca.pcaxes[0], index=pca.names)

# %%
df.to_csv(workDir+"/myersPopGen_main_094.pca_analysis.csv")

# %%
pca.draw(0,1)
# Out:
# (<toyplot.canvas.Canvas at 0x2b7f08a55df0>,
#  <toyplot.coordinates.Cartesian at 0x2b7f08a55e20>)
# <div class="toyplot" id="t4d94e373c698426fa309bac586f77085" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="ta9f996ef4de1450da619d6f8b22d941b"><g class="toyplot-coordinates-Cartesian" id="tdf85b4717b9f40f3bb384ff8f7ac9a46"><clipPath id="t8b59223333e24d8b902beffec4bf4740"><rect x="40.0" y="40.0" width="240.0" height="220.0"></rect></clipPath><g clip-path="url(#t8b59223333e24d8b902beffec4bf4740)"><g class="toyplot-mark-Point" id="t4833ac48a1e1495cbb5ec62059ad654c"><g class="toyplot-Series"><g style="fill:rgb(36.9%,31%,63.5%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(250.24177456814311, 183.74282845355313)"><title>MAD2017_330_S215001.trim</title><polygon points="-5.0,5.0 0,-5.0 5.0,5.0" transform="rotate(-90)"></polygon></g><g style="fill:rgb(99.7%,91.3%,60.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(225.90410702099408, 189.51992245382144)"><title>MAD2017_378_S218001.trim</title><polygon points="-5.0,5.0 0,-5.0 5.0,5.0" transform="rotate(-90)"></polygon></g><g style="fill:rgb(93%,97.2%,64%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(236.7406843434197, 207.16184045794165)"><title>YMF2018_040_S59001.trim</title><circle r="5.0"></circle></g><g style="fill:rgb(99.7%,91.3%,60.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(223.70293418516505, 216.98484880273963)"><title>YMF2018_041_S71001.trim</title><circle r="5.0"></circle></g><g style="fill:rgb(99.7%,91.3%,60.3%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(228.5151703811901, 223.91281755727022)"><title>YMF2018_042_S83001.trim</title><circle r="5.0"></circle></g><g style="fill:rgb(98.7%,64.6%,36.4%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(77.42233041408635, 186.52916891422333)"><title>YMF2018_044_S1001.trim</title><circle r="5.0"></circle></g><g style="fill:rgb(98.7%,64.6%,36.4%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(209.79836672347193, 206.86223214702025)"><title>YMF2018_045_S12001.trim</title><circle r="5.0"></circle></g><g style="fill:rgb(98.7%,64.6%,36.4%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(230.42500513962443, 66.16809805338906)"><title>YMF2018_046_S24001.trim</title><circle r="5.0"></circle></g><g style="fill:rgb(98.7%,64.6%,36.4%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(231.0236323970015, 198.6339195045239)"><title>YMF2018_047_S36001.trim</title><circle r="5.0"></circle></g><g style="fill:rgb(98.7%,64.6%,36.4%);fill-opacity:0.75;opacity:1.0;stroke:rgb(14.9%,14.9%,14.9%);stroke-opacity:1.0;stroke-width:1.5" class="toyplot-Datum" transform="translate(231.3813104135311, 207.7072765054623)"><title>YMF2018_048_S48001.trim</title><circle r="5.0"></circle></g><g style="fill:rgb(88.7%,32.2%,29%);fill-opacity:0.75;opacity:1.0;str ...
